# %% [markdown]
# ## Importing the Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Importing the Data

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## Setting the Index

# %%
df = df.set_index('id')

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %% [markdown]
# ## Checking the Null Values

# %%
def missing_percentage(df):
    total = df.isnull().sum().sort_values(ascending = False)[df.isnull().sum().sort_values(ascending = False)!= 0]
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100 , 2)[round(df.isnull().sum().sort_values(ascending = False)/len(df)*100 , 2)!= 0]
    data_type = df.dtypes.sort_values(ascending = False)[df.isnull().sum().sort_values(ascending = False)!= 0]
    return pd.concat([total , percent , data_type],axis = 1 , keys = ['Total' , 'Percent' , 'Type'])

# %%
missing_percentage(df)
# Out:
# Empty DataFrame
# Columns: [Total, Percent, Type]
# Index: []

# %%
#There are no Null Values in the data

# %% [markdown]
# ## Dealing with Data Types

# %%
#There are irrelevant data

# %%
df = df.drop(["date" , "zipcode"] , axis = 1)

# %%
df
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
# ...              ...       ...        ...          ...       ...     ...
# 263000018   360000.0         3       2.50         1530      1131     3.0
# 6600060120  400000.0         4       2.50         2310      5813     2.0
# 1523300141  402101.0         2       0.75         1020      1350     2.0
# 291310100   400000.0         3       2.50         1600      2388     2.0
# 1523300157  325000.0         2       0.75         1020      1076     2.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# ...

# %%
df.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#There are "float , int" data which is better to be "strings"

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df['bathrooms'].value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.25       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
df['bedrooms'] = df['bedrooms'].astype('str')
df['bathrooms'] = df['bathrooms'].astype('str')
df['floors'] = df['floors'].astype('str')
df['waterfront'] = df['waterfront'].astype('str')
df['view'] = df['view'].astype('str')
df['condition'] = df['condition'].astype('str')
df['grade'] = df['grade'].astype('str')
df['yr_built'] = df['yr_built'].astype('str')
df['yr_renovated'] = df['yr_renovated'].astype('str')

# %%
df.dtypes
# Out:
# price            float64
# bedrooms          object
# bathrooms         object
# sqft_living        int64
# sqft_lot           int64
# floors            object
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above         int64
# sqft_basement      int64
# yr_built          object
# yr_renovated      object
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ## Inserting a new column for better analysis

# %%
df.insert(18, 'total_sqft' , df['sqft_living'] + df['sqft_lot'] + df['sqft_above'] + df['sqft_basement'] + df['sqft_living15'] + df['sqft_lot15'])

# %%
df
# Out:
#                price bedrooms bathrooms  sqft_living  sqft_lot floors  \
# id
# 7129300520  221900.0        3       1.0         1180      5650    1.0
# 6414100192  538000.0        3      2.25         2570      7242    2.0
# 5631500400  180000.0        2       1.0          770     10000    1.0
# 2487200875  604000.0        4       3.0         1960      5000    1.0
# 1954400510  510000.0        3       2.0         1680      8080    1.0
# ...              ...      ...       ...          ...       ...    ...
# 263000018   360000.0        3       2.5         1530      1131    3.0
# 6600060120  400000.0        4       2.5         2310      5813    2.0
# 1523300141  402101.0        2      0.75         1020      1350    2.0
# 291310100   400000.0        3       2.5         1600      2388    2.0
# 1523300157  325000.0        2      0.75         1020      1076    2.0
#
#            waterfront view condition grade  sqft_above  sqft_basement  \
# id
# ...

# %% [markdown]
# ## Data Analysis

# %%
sns.distplot(df.price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.relplot("total_sqft","price",data=df  )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("condition","price",data=df , kind='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("yr_built","price",data=df )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("view","price",data=df , kind='bar' )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot("waterfront","price",data=df )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Importing the Packages

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#                price bedrooms bathrooms  sqft_living  sqft_lot floors  \
# id
# 7129300520  221900.0        3       1.0         1180      5650    1.0
# 6414100192  538000.0        3      2.25         2570      7242    2.0
# 5631500400  180000.0        2       1.0          770     10000    1.0
# 2487200875  604000.0        4       3.0         1960      5000    1.0
# 1954400510  510000.0        3       2.0         1680      8080    1.0
# ...              ...      ...       ...          ...       ...    ...
# 263000018   360000.0        3       2.5         1530      1131    3.0
# 6600060120  400000.0        4       2.5         2310      5813    2.0
# 1523300141  402101.0        2      0.75         1020      1350    2.0
# 291310100   400000.0        3       2.5         1600      2388    2.0
# 1523300157  325000.0        2      0.75         1020      1076    2.0
#
#            waterfront view condition grade  sqft_above  sqft_basement  \
# id
# ...

# %% [markdown]
# ## Splitting Input and Output

# %%
x = df.iloc[:,1:]

# %%
y = df.iloc[:,0].to_frame()

# %%
x
# Out:
#            bedrooms bathrooms  sqft_living  sqft_lot floors waterfront view  \
# id
# 7129300520        3       1.0         1180      5650    1.0          0    0
# 6414100192        3      2.25         2570      7242    2.0          0    0
# 5631500400        2       1.0          770     10000    1.0          0    0
# 2487200875        4       3.0         1960      5000    1.0          0    0
# 1954400510        3       2.0         1680      8080    1.0          0    0
# ...             ...       ...          ...       ...    ...        ...  ...
# 263000018         3       2.5         1530      1131    3.0          0    0
# 6600060120        4       2.5         2310      5813    2.0          0    0
# 1523300141        2      0.75         1020      1350    2.0          0    0
# 291310100         3       2.5         1600      2388    2.0          0    0
# 1523300157        2      0.75         1020      1076    2.0          0    0
#
# ...

# %%
y
# Out:
#                price
# id
# 7129300520  221900.0
# 6414100192  538000.0
# 5631500400  180000.0
# 2487200875  604000.0
# 1954400510  510000.0
# ...              ...
# 263000018   360000.0
# 6600060120  400000.0
# 1523300141  402101.0
# 291310100   400000.0
# 1523300157  325000.0
#
# [21613 rows x 1 columns]

# %% [markdown]
# ## Data Encoding

# %%
x_obj = x.select_dtypes(include = ["object"])
x_non_obj = x.select_dtypes(exclude = ["object"])

# %%
x_obj
# Out:
#            bedrooms bathrooms floors waterfront view condition grade yr_built  \
# id
# 7129300520        3       1.0    1.0          0    0         3     7     1955
# 6414100192        3      2.25    2.0          0    0         3     7     1951
# 5631500400        2       1.0    1.0          0    0         3     6     1933
# 2487200875        4       3.0    1.0          0    0         5     7     1965
# 1954400510        3       2.0    1.0          0    0         3     8     1987
# ...             ...       ...    ...        ...  ...       ...   ...      ...
# 263000018         3       2.5    3.0          0    0         3     8     2009
# 6600060120        4       2.5    2.0          0    0         3     8     2014
# 1523300141        2      0.75    2.0          0    0         3     7     2009
# 291310100         3       2.5    2.0          0    0         3     8     2004
# 1523300157        2      0.75    2.0          0    0         3     7     2008
#
#            yr_renovated
# ...

# %%
x_non_obj
# Out:
#             sqft_living  sqft_lot  sqft_above  sqft_basement      lat  \
# id
# 7129300520         1180      5650        1180              0  47.5112
# 6414100192         2570      7242        2170            400  47.7210
# 5631500400          770     10000         770              0  47.7379
# 2487200875         1960      5000        1050            910  47.5208
# 1954400510         1680      8080        1680              0  47.6168
# ...                 ...       ...         ...            ...      ...
# 263000018          1530      1131        1530              0  47.6993
# 6600060120         2310      5813        2310              0  47.5107
# 1523300141         1020      1350        1020              0  47.5944
# 291310100          1600      2388        1600              0  47.5345
# 1523300157         1020      1076        1020              0  47.5941
#
#                long  sqft_living15  sqft_lot15  total_sqft
# id
# ...

# %%
la = LabelEncoder()
for i in range (x_obj.shape[1]):
    x_obj.iloc[:,i] = la.fit_transform(x_obj.iloc[:,i])

# %%
x_obj
# Out:
#             bedrooms  bathrooms  floors  waterfront  view  condition  grade  \
# id
# 7129300520         5          3       0           0     0          2      9
# 6414100192         5          8       2           0     0          2      9
# 5631500400         4          3       0           0     0          2      8
# 2487200875         7         11       0           0     0          4      9
# 1954400510         5          7       0           0     0          2     10
# ...              ...        ...     ...         ...   ...        ...    ...
# 263000018          5          9       4           0     0          2     10
# 6600060120         7          9       2           0     0          2     10
# 1523300141         4          2       2           0     0          2      9
# 291310100          5          9       2           0     0          2     10
# 1523300157         4          2       2           0     0          2      9
#
#             yr_built  yr_renovated
# id
# ...

# %%
X = pd.concat([x_non_obj,x_obj] , axis=1)

# %%
X
# Out:
#             sqft_living  sqft_lot  sqft_above  sqft_basement      lat  \
# id
# 7129300520         1180      5650        1180              0  47.5112
# 6414100192         2570      7242        2170            400  47.7210
# 5631500400          770     10000         770              0  47.7379
# 2487200875         1960      5000        1050            910  47.5208
# 1954400510         1680      8080        1680              0  47.6168
# ...                 ...       ...         ...            ...      ...
# 263000018          1530      1131        1530              0  47.6993
# 6600060120         2310      5813        2310              0  47.5107
# 1523300141         1020      1350        1020              0  47.5944
# 291310100          1600      2388        1600              0  47.5345
# 1523300157         1020      1076        1020              0  47.5941
#
#                long  sqft_living15  sqft_lot15  total_sqft  bedrooms  \
# id
# ...

# %% [markdown]
# ## Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X , y , train_size = .9)

# %% [markdown]
# ## Data Fitting

# %%
model = RandomForestRegressor()

# %%
model.fit (X_train, y_train)
# Out:
# C:\Users\TEBA\AppData\Local\Temp\ipykernel_3404\4167468156.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit (X_train, y_train)
# RandomForestRegressor()

# %% [markdown]
# ## Examine the Model

# %%
print(model.score(X_train, y_train))
# Out:
# 0.9824524398472103

# %%
print(model.score(X_test, y_test))
# Out:
# 0.8895610307479329
